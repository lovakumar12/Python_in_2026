# %% [markdown]
# <a href="https://colab.research.google.com/github/lovakumar12/Python_in_2026/blob/main/Python_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tuples**

# %%
aa=(1,2,345,45,"Lova","jitin")

# %% [markdown]
# ## **Indexing**

# %%
aa[2]
# Out:
# 345

# %%
aa[5]
# Out:
# 'jitin'

# %%
aa[-3]
# Out:
# 45

# %% [markdown]
# ## **slicing**

# %%
print(aa)
# Out:
# (1, 2, 345, 45, 'Lova', 'jitin')

# %%
aa[1:4]
# Out:
# (2, 345, 45)

# %%
aa[:5]
# Out:
# (1, 2, 345, 45, 'Lova')

# %%
aa[3:6]
# Out:
# (45, 'Lova', 'jitin')

# %%
aa[0:6:1]
# Out:
# (1, 2, 345, 45, 'Lova', 'jitin')

# %%
aa[0:5:2]
# Out:
# (1, 345, 'Lova')

# %%
aa[-4:-1:1]
# Out:
# (345, 45, 'Lova')

# %%
aa[::-1]
# Out:
# ('jitin', 'Lova', 45, 345, 2, 1)

# %% [markdown]
# ## **Functions**

# %%
a=(1,23,32,45,78,2,34546,7)

# %%
print(len(a))
print(min(a))
print(max(a))
print(sorted(a))
# Out:
# 8
# 1
# 34546
# [1, 2, 7, 23, 32, 45, 78, 34546]

# %%
print(a)
# Out:
# (1, 23, 32, 45, 78, 2, 34546, 7)

# %% [markdown]
# ## immumutability

# %% [markdown]
# ## **Methods**

# %%
a1=(1,2,3,1,45,34,56,67,"Hi")

# %%
a1.count(1)
# Out:
# 2

# %%
a1.index(45)
# Out:
# 4
